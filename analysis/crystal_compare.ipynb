# %%
import numpy as np
import matplotlib.pyplot as plt

# 加载两组平衡构型
d1 = np.load("../outputs/550+50Trap/npz/fx225fy737fz131.npz")
d2 = np.load("../outputs/550+50Trap/npz/fx449fy1473fz261.npz")
r1, r2 = d1["r"], d2["r"]  # (N, 3): x, y, z (μm)

# zox 面投影：z 为横轴，x 为纵轴
fig, ax = plt.subplots(figsize=(12, 4))
ax.scatter(r1[:, 2], r1[:, 0], s=20, c="red", label="fx225 fy737 fz131", zorder=3)
ax.scatter(r2[:, 2], r2[:, 0], s=20, c="blue", label="fx449 fy1473 fz261", zorder=3)
ax.set_xlabel("z (μm)", fontsize=13)
ax.set_ylabel("x (μm)", fontsize=13)
ax.set_aspect("equal")
ax.legend(fontsize=11)
ax.set_title("zox projection — crystal comparison", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import numpy as np

experiment_crystal = np.array([[25.62643829, 315.51444888],
 [ 12.47011929, 333.87628923],
 [ 39.43214986, 333.56874801],
 [ 25.89937037, 349.48387405],   
 [  7.8406468,  359.46182197],
 [ 44.39767515, 358.65220409],
 [ 26.33233605, 371.04496327],
 [  8.09092126, 383.20638404],
 [ 44.96085619, 382.6369608 ],
 [ 26.60010497, 392.72440666],
 [ 40.21273477, 408.25532868],
 [ 13.7156107,  408.72068108],
 [ 27.79159471, 426.62975339]])
# Out:
# [[ 25.62643829 315.51444888]
#  [ 12.47011929 333.87628923]
#  [ 39.43214986 333.56874801]
#  [ 25.89937037 349.48387405]
#  [  7.8406468  359.46182197]
#  [ 44.39767515 358.65220409]
#  [ 26.33233605 371.04496327]
#  [  8.09092126 383.20638404]
#  [ 44.96085619 382.6369608 ]
#  [ 26.60010497 392.72440666]
#  [ 40.21273477 408.25532868]
#  [ 13.7156107  408.72068108]
#  [ 27.79159471 426.62975339]]

# %%
# 比较Comsol网格和多项式拟合出来的晶格
import numpy as np
import matplotlib.pyplot as plt

# 加载两组平衡构型
d1 = np.load("../outputs/300+50Trap/1000.npz")
d2 = np.load("../outputs/300+50Trap/1000_poly.npz")
r1, r2 = d1["r"], d2["r"]  # (N, 3): x, y, z (μm)

# zox 面投影：z 为横轴，x 为纵轴
fig, ax = plt.subplots(figsize=(12, 4))
ax.scatter(r1[:, 2], r1[:, 0], s=20, c="red", label="Comsol", zorder=3)
ax.scatter(r2[:, 2], r2[:, 0], s=20, c="blue", label="Poly", zorder=3)
ax.set_xlabel("z (μm)", fontsize=13)
ax.set_ylabel("x (μm)", fontsize=13)
ax.set_aspect("equal")
ax.legend(fontsize=11)
ax.set_title("zox projection — crystal comparison", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# 比较两次随机初始条件下Comsol网格算出来的晶格
import numpy as np
import matplotlib.pyplot as plt

# 加载两组平衡构型
d1 = np.load("../outputs/300+50Trap/1000.npz")
d2 = np.load("../outputs/300+50Trap/1000-2.npz")
r1, r2 = d1["r"], d2["r"]  # (N, 3): x, y, z (μm)

# zox 面投影：z 为横轴，x 为纵轴
fig, ax = plt.subplots(figsize=(12, 4))
ax.scatter(r1[:, 2], r1[:, 0], s=20, c="red", label="Comsol", zorder=3)
ax.scatter(r2[:, 2], r2[:, 0], s=20, c="blue", label="Comsol-2", zorder=3)
ax.set_xlabel("z (μm)", fontsize=13)
ax.set_ylabel("x (μm)", fontsize=13)
ax.set_aspect("equal")
ax.legend(fontsize=11)
ax.set_title("zox projection — crystal comparison", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# 比较Poly和Poly_sym晶格的区别
import numpy as np
import matplotlib.pyplot as plt

# 加载两组平衡构型
d1 = np.load("../outputs/300+50Trap/1000_poly.npz")
d2 = np.load("../outputs/300+50Trap/1000_poly_sym.npz")
r1, r2 = d1["r"], d2["r"]  # (N, 3): x, y, z (μm)

# zox 面投影：z 为横轴，x 为纵轴
fig, ax = plt.subplots(figsize=(12, 4))
ax.scatter(r1[:, 2], r1[:, 0], s=20, c="red", label="poly", zorder=3)
ax.scatter(r2[:, 2], r2[:, 0], s=20, c="blue", label="poly_sym", zorder=3)
ax.set_xlabel("z (μm)", fontsize=13)
ax.set_ylabel("x (μm)", fontsize=13)
ax.set_aspect("equal")
ax.legend(fontsize=11)
ax.set_title("zox projection — crystal comparison", fontsize=14)
plt.tight_layout()
plt.show()
