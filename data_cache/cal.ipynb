# %%
import numpy as np

r = np.loadtxt('r.txt')
cf = np.loadtxt('coulomb.txt')

# Coulomb force based on r
print(r.shape)
rf_1 = -2*r[0]/(2*np.linalg.norm(r[0]))**3
print(np.linalg.norm(cf[0]))
# Out:
# (2, 3)
# 0.9999999302499976
